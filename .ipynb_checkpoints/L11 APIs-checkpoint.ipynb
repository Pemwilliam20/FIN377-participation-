# %%
import pandas as pd
# pandas does html?!
all_tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
constitutents = all_tables[0] # it will download all tables on the page to a "list of dataframes"
constitutents # no urls :( just the raw text! 

# requests / requests_html seem like a good combo
# Out:
#     Symbol                Security SEC filings             GICS Sector  \
# 0      MMM              3M Company     reports             Industrials
# 1      ABT     Abbott Laboratories     reports             Health Care
# 2     ABBV             AbbVie Inc.     reports             Health Care
# 3     ABMD             ABIOMED Inc     reports             Health Care
# 4      ACN           Accenture plc     reports  Information Technology
# ..     ...                     ...         ...                     ...
# 500    YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA      Zebra Technologies     reports  Information Technology
# 502    ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503   ZION           Zions Bancorp     reports              Financials
# 504    ZTS                  Zoetis     reports             Health Care
#
#                       GICS Sub Industry     Headquarters Location  \
# 0              Industrial Conglomerates       St. Paul, Minnesota
# 1                 Health Care Equipment   North Chicago, Illinois
# 2                       Pharmaceuticals   North Chicago, Illinois
# 3                 Health Care Equipment    Danvers, Massachusetts
# 4        IT Consulting & Other Services           Dublin, Ireland
# ..                                  ...                       ...
# 500                         Restaurants      Louisville, Kentucky
# 501  Electronic Equipment & Instruments    Lincolnshire, Illinois
# 502               Health Care Equipment           Warsaw, Indiana
# 503                      Regional Banks      Salt Lake City, Utah
# 504                     Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK      Founded
# 0                NaN    66740         1902
# 1         1964-03-31     1800         1888
# 2         2012-12-31  1551152  2013 (1888)
# 3         2018-05-31   815094         1981
# 4         2011-07-06  1467373         1989
# ..               ...      ...          ...
# 500       1997-10-06  1041061          NaN
# 501       2019-12-23   877212         1969
# 502       2001-08-07  1136869          NaN
# 503       2001-06-22   109380          NaN
# 504       2013-06-21  1555280          NaN
#
# [505 rows x 9 columns]

# %%
import requests 
base_url = 'http://chroniclingamerica.loc.gov/search/pages/results/'
parameters = '?andtext=lynching&format=json'

url = base_url + parameters 
print(url)
r = requests.get(base_url + parameters)
# Out:
# http://chroniclingamerica.loc.gov/search/pages/results/?andtext=lynching&format=json

# %%
r.status_code # 200 menass you get a good result
# Out:
# 200

# %%
r 
r.json()
search_json = r.json() 
search_json.keys() # get a list of the keys ("elements"?)
search_json['totalItems'] # access element like in pandas
# Out:
# 1000393

# %%
type(search_json['items']) # items is a list of items
len(search_json['items']) # 20 items / 20 articles 
search_json['items'][0].keys() # works on each item
search_json['items'][0]['title']
# Out:
# 'Dearborn independent. [volume]'

# %%
# pandas can IMPORT JSON INTO A DF
pd.DataFrame(search_json['items'])
# Out:
#     sequence                    county edition  \
# 0          1                   [Wayne]    None
# 1          4             [Cook County]    None
# 2          4                   [Hinds]    None
# 3         34                    [None]    None
# 4          4                    [King]    None
# 5         12             [Cook County]    None
# 6        123                    [None]    None
# 7          2                [Newberry]    None
# 8          2                  [Marion]    None
# 9         26                [Hartford]    None
# 10         4             [Cook County]    None
# 11         5                    [None]    None
# 12        12                   [Wayne]    None
# 13        13             [Cook County]    None
# 14        27             [Cook County]    None
# 15         2                  [Holmes]    None
# 16         1                [Maricopa]    None
# 17         9                  [Marion]    None
# 18         2  [Cook, Hennepin, Ramsey]    None
# 19         2              [Montgomery]    None
#
#                              frequency  \
# 0                               Weekly
# 1   Daily (except Sunday and holidays)
# 2                               Weekly
# 3                                Daily
# 4                               Weekly
# 5   Daily (except Sunday and holidays)
# 6                                Daily
# 7                               Weekly
# 8                Daily (except Sunday)
# 9                  Daily (except Sun.)
# 10  Daily (except Sunday and holidays)
# 11                               Daily
# 12                              Weekly
# 13  Daily (except Sunday and holidays)
# 14  Daily (except Sunday and holidays)
# 15                              Weekly
# 16                              Weekly
# 17                               Daily
# 18                              Weekly
# 19                 Daily (except Sun.)
#
#                                            id  \
# 0     /lccn/2013218776/1921-10-22/ed-1/seq-1/
# 1     /lccn/sn83045487/1915-08-18/ed-1/seq-4/
# 2     /lccn/sn79000083/1947-06-14/ed-1/seq-4/
# 3    /lccn/sn83045462/1922-11-23/ed-1/seq-34/
# 4     /lccn/sn87093353/1918-06-08/ed-1/seq-4/
# 5    /lccn/sn83045487/1913-05-07/ed-1/seq-12/
# 6   /lccn/sn83045462/1952-02-10/ed-1/seq-123/
# 7     /lccn/sn86063758/1904-10-18/ed-1/seq-2/
# 8     /lccn/sn84027621/1920-03-23/ed-1/seq-2/
# 9    /lccn/sn82014519/1926-03-26/ed-1/seq-26/
# 10    /lccn/sn83045487/1912-09-09/ed-1/seq-4/
# 11    /lccn/sn83045462/1933-11-30/ed-1/seq-5/
# 12   /lccn/2013218776/1921-10-22/ed-1/seq-12/
# 13   /lccn/sn83045487/1913-10-14/ed-1/seq-13/
# 14   /lccn/sn83045487/1914-10-13/ed-1/seq-27/
# 15    /lccn/sn87065228/1948-03-11/ed-1/seq-2/
# 16    /lccn/sn95060626/1937-05-14/ed-1/seq-1/
# 17    /lccn/sn82015313/1934-11-09/ed-1/seq-9/
# 18    /lccn/sn83016810/1922-12-02/ed-1/seq-2/
# 19    /lccn/sn88077226/1948-01-21/ed-1/seq-2/
#
#                                               subject  \
# 0   [Dearborn (Mich.)--Newspapers., Michigan--Dear...
# 1   [Chicago (Ill.)--Newspapers., Illinois--Chicag...
# 2   [African Americans--Mississippi--Newspapers., ...
# 3   [Washington (D.C.)--fast--(OCoLC)fst01204505, ...
# 4   [African Americans--Washington (State)--Seattl...
# 5   [Chicago (Ill.)--Newspapers., Illinois--Chicag...
# 6   [Washington (D.C.)--fast--(OCoLC)fst01204505, ...
# 7   [Newberry County (S.C.)--Newspapers., South Ca...
# 8   [Florida--Marion County.--fast--(OCoLC)fst0120...
# 9   [Connecticut--Hartford County.--fast--(OCoLC)f...
# 10  [Chicago (Ill.)--Newspapers., Illinois--Chicag...
# 11  [Washington (D.C.)--fast--(OCoLC)fst01204505, ...
# 12  [Dearborn (Mich.)--Newspapers., Michigan--Dear...
# 13  [Chicago (Ill.)--Newspapers., Illinois--Chicag...
# 14  [Chicago (Ill.)--Newspapers., Illinois--Chicag...
# 15                                                 []
# 16  [African Americans--Newspapers., African Ameri...
# 17  [Indiana--Indianapolis.--fast--(OCoLC)fst01205...
# 18  [African American newspapers--Illinois., Afric...
# 19  [African Americans--Ohio--Dayton--Newspapers.,...
#
#                                   city      date  \
# 0                           [Dearborn]  19211022
# 1                            [Chicago]  19150818
# 2                            [Jackson]  19470614
# 3                         [Washington]  19221123
# 4                            [Seattle]  19180608
# 5                            [Chicago]  19130507
# 6                         [Washington]  19520210
# 7                           [Newberry]  19041018
# 8                              [Ocala]  19200323
# 9                        [New Britain]  19260326
# 10                           [Chicago]  19120909
# 11                        [Washington]  19331130
# 12                          [Dearborn]  19211022
# 13                           [Chicago]  19131014
#
# [20 rows x 28 columns]

# %% [markdown]
# # CLASS ACTIVITY - RUN YOUR OWN SEARCH
# # pick a crime and search for it, store the output in a dataframe

# %%
import requests 
base_url = 'http://chroniclingamerica.loc.gov/search/pages/results/'
parameters = '?andtext=grandlarceny&format=json'

url = base_url + parameters 
print(url)
r2 = requests.get(base_url + parameters)
# Out:
# http://chroniclingamerica.loc.gov/search/pages/results/?andtext=grandlarceny&format=json

# %%
r2.status_code # 200 means you get a good result
# Out:
# 200

# %%
r2 
r2.json()
search_json = r2.json() 
search_json.keys() # get a list of the keys ("elements"?)
search_json['totalItems'] # access element like in pandas
# Out:
# 902

# %%
type(search_json['items']) # items is a list of items
len(search_json['items']) # 20 items / 20 articles 
search_json['items'][0].keys() # works on each item
search_json['items'][0]['title']
# Out:
# 'The sun. [volume]'

# %%
# pandas can IMPORT JSON INTO A DF
pd.DataFrame(search_json['items'])
# Out:
#     sequence       county    edition                frequency  \
# 0          2   [New York]       None                    Daily
# 1          7  [Salt Lake]       None                    Daily
# 2         16     [Putnam]       None                   Weekly
# 3         12       [None]       None    Daily (except Sunday)
# 4          8  [Salt Lake]       None                    Daily
# 5          4   [Escambia]       None                    Daily
# 6          5    [Bourbon]       None               Semiweekly
# 7          8       [None]       None    Daily (except Sunday)
# 8          7   [New York]       None                    Daily
# 9         10  [Salt Lake]       None                    Daily
# 10        23  [Salt Lake]       None                    Daily
# 11         4       [None]       None    Daily (except Sunday)
# 12        12   [New York]       None                    Daily
# 13         8  [Salt Lake]       None                    Daily
# 14        27       [None]       None    Daily (except Sunday)
# 15         1    [Bourbon]       None               Semiweekly
# 16         1       [Elko]       None    Daily (except Sunday)
# 17         1   [Faulkner]  Daily ed.  Daily (except Saturday)
# 18         1    [Alachua]       None  Daily (except Saturday)
# 19         1    [Bourbon]       None               Semiweekly
#
#                                           id  \
# 0    /lccn/sn83030272/1909-08-09/ed-1/seq-2/
# 1    /lccn/sn85058140/1910-10-29/ed-1/seq-7/
# 2   /lccn/sn95047348/1909-03-20/ed-1/seq-16/
# 3   /lccn/sn84026749/1906-02-10/ed-1/seq-12/
# 4    /lccn/sn85058130/1907-01-06/ed-1/seq-8/
# 5    /lccn/sn87062268/1906-05-15/ed-1/seq-4/
# 6    /lccn/sn86069873/1906-03-20/ed-1/seq-5/
# 7    /lccn/sn84024441/1900-06-18/ed-1/seq-8/
# 8    /lccn/sn83030272/1904-02-07/ed-1/seq-7/
# 9   /lccn/sn85058130/1906-11-09/ed-1/seq-10/
# 10  /lccn/sn85058130/1906-09-09/ed-1/seq-23/
# 11   /lccn/sn84026749/1909-04-14/ed-1/seq-4/
# 12  /lccn/sn83030272/1903-07-22/ed-1/seq-12/
# 13   /lccn/sn85058130/1906-07-13/ed-1/seq-8/
# 14  /lccn/sn84026749/1904-05-01/ed-1/seq-27/
# 15   /lccn/sn86069873/1906-05-04/ed-1/seq-1/
# 16   /lccn/sn84020355/1913-09-06/ed-1/seq-1/
# 17   /lccn/sn85033000/1911-06-08/ed-1/seq-1/
# 18   /lccn/sn95026977/1909-07-01/ed-1/seq-1/
# 19   /lccn/sn86069873/1906-04-13/ed-1/seq-1/
#
#                                               subject              city  \
# 0   [New York (N.Y.)--Newspapers., New York (State...        [New York]
# 1   [Salt Lake City (Utah)--Newspapers., Utah--Sal...  [Salt Lake City]
# 2   [Florida--Putnam County.--fast--(OCoLC)fst0121...       [San Mateo]
# 3   [Washington (D.C.)--fast--(OCoLC)fst01204505, ...      [Washington]
# 4   [Salt Lake City (Utah)--Newspapers., Salt Lake...  [Salt Lake City]
# 5   [Escambia County (Fla.)--Newspapers., Florida-...       [Pensacola]
# 6   [Bourbon County (Ky.)--Newspapers., Kentucky--...           [Paris]
# 7   [Washington (D.C.)--fast--(OCoLC)fst01204505, ...      [Washington]
# 8   [New York (N.Y.)--Newspapers., New York (State...        [New York]
# 9   [Salt Lake City (Utah)--Newspapers., Salt Lake...  [Salt Lake City]
# 10  [Salt Lake City (Utah)--Newspapers., Salt Lake...  [Salt Lake City]
# 11  [Washington (D.C.)--fast--(OCoLC)fst01204505, ...      [Washington]
# 12  [New York (N.Y.)--Newspapers., New York (State...        [New York]
# 13  [Salt Lake City (Utah)--Newspapers., Salt Lake...  [Salt Lake City]
# 14  [Washington (D.C.)--fast--(OCoLC)fst01204505, ...      [Washington]
# 15  [Bourbon County (Ky.)--Newspapers., Kentucky--...           [Paris]
# 16  [Elko (Nev.)--Newspapers., Nevada--Elko.--fast...            [Elko]
# 17  [Arkansas--Conway.--fast--(OCoLC)fst01218757, ...          [Conway]
# 18  [Alachua County (Fla.)--Newspapers., Florida--...     [Gainesville]
# 19  [Bourbon County (Ky.)--Newspapers., Kentucky--...           [Paris]
#
#         date                                      title  end_year  ...  \
# 0   19090809                          The sun. [volume]      1916  ...
# 1   19101029  The Salt Lake herald-Republican. [volume]      1918  ...
# 2   19090320                        The San Mateo item.      1999  ...
# 3   19060210             The Washington times. [volume]      1939  ...
# 4   19070106             The Salt Lake herald. [volume]      1909  ...
# 5   19060515                     The Pensacola journal.      1985  ...
# 6   19060320                 The Bourbon news. [volume]      1999  ...
# 7   19000618                The evening times. [volume]      1902  ...
# 8   19040207                          The sun. [volume]      1916  ...
# 9   19061109             The Salt Lake herald. [volume]      1909  ...
# 10  19060909             The Salt Lake herald. [volume]      1909  ...
# 11  19090414             The Washington times. [volume]      1939  ...
# 12  19030722                          The sun. [volume]      1916  ...
# 13  19060713             The Salt Lake herald. [volume]      1909  ...
# 14  19040501             The Washington times. [volume]      1939  ...
# 15  19060504                 The Bourbon news. [volume]      1999  ...
# 16  19130906                Daily independent. [volume]      1915  ...
# 17  19110608           The Log cabin Democrat. [volume]      9999  ...
# 18  19090701                     Gainesville daily sun.      1938  ...
# 19  19060413                 The Bourbon news. [volume]      1999  ...
#
#      language                                          alt_title        lccn  \
# 0   [English]                          [Extra sun, New York sun]  sn83030272
# 1   [English]  [Herald-Republican, Salt Lake herald-Republica...  sn85058140
# 2   [English]                                             [Item]  sn95047348
# 3   [English]                          [Washington times herald]  sn84026749
# 4   [English]            [Salt Lake daily herald, Sunday herald]  sn85058130
# 5   [English]            [Daily journal, Pensacola news-journal]  sn87062268
# 6   [English]                                                 []  sn86069873
# 7   [English]                                                 []  sn84024441
# 8   [English]                          [Extra sun, New York sun]  sn83030272
# 9   [English]            [Salt Lake daily herald, Sunday herald]  sn85058130
# 10  [English]            [Salt Lake daily herald, Sunday herald]  sn85058130
# 11  [English]                          [Washington times herald]  sn84026749
# 12  [English]                          [Extra sun, New York sun]  sn83030272
# 13  [English]            [Salt Lake daily herald, Sunday herald]  sn85058130
# 14  [English]                          [Washington times herald]  sn84026749
# 15  [English]                                                 []  sn86069873
# 16  [English]   [Daily Elko independent, Elko daily independent]  sn84020355
# 17  [English]                                                 []  sn85033000
# 18  [English]                                   [Daily sun, Sun]  sn95026977
# 19  [English]                                                 []  sn86069873
#
#                  country                                            ocr_eng  \
# 0               New York  o oI\nt\nt I t THE suN SU N MONDAY I ND Y AUGU...
# 1                   Utah  F\nTHE TH HE HERALDREPUBLICAN SALT LAKE KE CIT...
# 2                Florida  V\n1 1y\ny\na\nI\nc c c9c51\nd w1Aila r r + rr...
# 3   District of Columbia  12 TIT Wi1SHL1G0N V SHLJGfON TIMES SATURDAY Yy...
# 4                   Utah  ir s ili iliS\nt\n8 THE SALT LAKE HERALD SUNDA...
# 5                Florida  7 7t3\nC1Ma g + v\ni\nr t\nT TPAGE\ni\nPAGE FO...
# 6               Kentucky  Y\n4 m mTHE\nr THE HE BOUR BOURBON ON NEWS PAR...
# 7   District of Columbia  Th ThS\nr\n8 THE EVENING Evnth TIMES WASHINGTO...
# 8               New York  J i\nj > J <\nf\n1\nges gesThe\nThe Thehi\nhi ...
# 9                   Utah  10 THE SALT LAKE HERALD T FRIDAY ThAY NOYEMKER...
# 10                  Utah  NEWS SECTION THE SALT LAKE L KE HERALD SUNDAY ...
# 11  District of Columbia  4 THE WASHZNTrTOX WA HIXGTOX TIMES WEDNESDAY W...
# 12              New York  T I\n1\n12 THE SUN WEDNESDAY JULY 22 1903 <\nI...
# 13                  Utah  i =\nI S THE SALT LAKE HERALD D FRIDAY RID Y i...
# 14  District of Columbia  ii\n2 THE WASHINGTON TIMES SUNDAY MAY 1 1 1904...
# 15              Kentucky  I z\n1 THE BOURBON NEWS1 NEWS1t y ifS ifSy\nft...
# 16                Nevada  ?E,i ^dorado Of The West"?Home Builders Wanted...
# 17              Arkansas  The L< ig Cabin Democrat.\ni _ DAILY EDITION_\...
# 18               Florida  < r J\n4ti 4tiVOL\nr\nf j r iw 1I 1Ia 1IVon\nT...
# 19              Kentucky  v\nV 4 VT1 7 ± ± < tr > L zAr Jr x f k i T H E...
#
#                    batch                  title_normal  \
# 0         nn_james_ver01                          sun.
# 1         uuml_six_ver01  salt lake herald-republican.
# 2          fu_nine_ver01               san mateo item.
# 3       dlc_yankee_ver01             washington times.
# 4        uuml_five_ver01             salt lake herald.
# 5           fu_ten_ver01            pensacola journal.
# 6      kyu_beatles_ver01                 bourbon news.
# 7         dlc_mike_ver01                evening times.
# 8      nn_epicurus_ver01                          sun.
# 9        uuml_five_ver01             salt lake herald.
# 10       uuml_five_ver01             salt lake herald.
# 11     dlc_uniform_ver01             washington times.
# 12     nn_decartes_ver01                          sun.
# 13       uuml_five_ver01             salt lake herald.
# 14      dlc_quebec_ver01             washington times.
# 15     kyu_beatles_ver01                 bourbon news.
# 16  nvln_manhattan_ver01            daily independent.
# 17  arhi_bulbasaur_ver01           log cabin democrat.
# 18        fu_three_ver01        gainesville daily sun.
# 19     kyu_beatles_ver01                 bourbon news.
#
#                                                   url  \
# 0   https://chroniclingamerica.loc.gov/lccn/sn8303...
# 1   https://chroniclingamerica.loc.gov/lccn/sn8505...
# 2   https://chroniclingamerica.loc.gov/lccn/sn9504...
# 3   https://chroniclingamerica.loc.gov/lccn/sn8402...
# 4   https://chroniclingamerica.loc.gov/lccn/sn8505...
# 5   https://chroniclingamerica.loc.gov/lccn/sn8706...
# 6   https://chroniclingamerica.loc.gov/lccn/sn8606...
# 7   https://chroniclingamerica.loc.gov/lccn/sn8402...
# 8   https://chroniclingamerica.loc.gov/lccn/sn8303...
# 9   https://chroniclingamerica.loc.gov/lccn/sn8505...
# 10  https://chroniclingamerica.loc.gov/lccn/sn8505...
# 11  https://chroniclingamerica.loc.gov/lccn/sn8402...
# 12  https://chroniclingamerica.loc.gov/lccn/sn8303...
# 13  https://chroniclingamerica.loc.gov/lccn/sn8505...
# 14  https://chroniclingamerica.loc.gov/lccn/sn8402...
# 15  https://chroniclingamerica.loc.gov/lccn/sn8606...
# 16  https://chroniclingamerica.loc.gov/lccn/sn8402...
# 17  https://chroniclingamerica.loc.gov/lccn/sn8503...
# 18  https://chroniclingamerica.loc.gov/lccn/sn9502...
# 19  https://chroniclingamerica.loc.gov/lccn/sn8606...
#
#                                  place       page
# 0       [New York--New York--New York]          2
# 1    [Utah--Salt Lake--Salt Lake City]          7
# 2         [Florida--Putnam--San Mateo]
# 3   [District of Columbia--Washington]         12
# 4    [Utah--Salt Lake--Salt Lake City]          8
# 5       [Florida--Escambia--Pensacola]  Page Four
# 6           [Kentucky--Bourbon--Paris]
# 7   [District of Columbia--Washington]          8
# 8       [New York--New York--New York]          7
# 9    [Utah--Salt Lake--Salt Lake City]         10
# 10   [Utah--Salt Lake--Salt Lake City]         11
# 11  [District of Columbia--Washington]          4
# 12      [New York--New York--New York]         12
# 13   [Utah--Salt Lake--Salt Lake City]          8
# 14  [District of Columbia--Washington]          2
# 15          [Kentucky--Bourbon--Paris]
# 16                [Nevada--Elko--Elko]
# 17        [Arkansas--Faulkner--Conway]
# 18     [Florida--Alachua--Gainesville]
# 19          [Kentucky--Bourbon--Paris]
#
# [20 rows x 28 columns]

# %% [markdown]
# # Exchange Rate Database Exercise

# %%
# q2 - change base currency, and do jan 2, 2018 
# url = 'https://api.exchangeratesapi.io/history?base=EUR''
base_url = 'https://api.exchangeratesapi.io/history?start_at=2018-01-02&end_at=2018-01-02'
x = requests.get(base_url)
x
print(base_url)
# Out:
# https://api.exchangeratesapi.io/history?start_at=2018-01-02&end_at=2018-01-02

# %%
base_url = 'https://api.exchangeratesapi.io/history?start_at=2018-01-02&end_at=2019-12-31'
x = requests.get(base_url)
df = pd.DataFrame(x.json())
df['EUROJPY'] = df['rates'].apply(lambda x: x.get('JPY'))
df
# Out:
#                                                         rates    start_at  \
# 2018-01-02  {'CAD': 1.5128, 'HKD': 9.4283, 'SGD': 1.6031, ...  2018-01-02
# 2018-01-03  {'CAD': 1.5047, 'HKD': 9.3985, 'SGD': 1.5988, ...  2018-01-02
# 2018-01-04  {'CAD': 1.5114, 'HKD': 9.4323, 'SGD': 1.6043, ...  2018-01-02
# 2018-01-05  {'CAD': 1.5068, 'HKD': 9.4188, 'SGD': 1.5993, ...  2018-01-02
# 2018-01-08  {'CAD': 1.488, 'HKD': 9.3656, 'SGD': 1.5956, '...  2018-01-02
# ...                                                       ...         ...
# 2019-12-23  {'CAD': 1.4577, 'HKD': 8.6232, 'ISK': 135.4, '...  2018-01-02
# 2019-12-24  {'CAD': 1.4582, 'HKD': 8.629, 'ISK': 135.6, 'P...  2018-01-02
# 2019-12-27  {'CAD': 1.4592, 'HKD': 8.6845, 'ISK': 135.6, '...  2018-01-02
# 2019-12-30  {'CAD': 1.4621, 'HKD': 8.7133, 'ISK': 135.8, '...  2018-01-02
# 2019-12-31  {'CAD': 1.4598, 'HKD': 8.7473, 'ISK': 135.8, '...  2018-01-02
#
#            base      end_at  EUROJPY
# 2018-01-02  EUR  2019-12-31   135.35
# 2018-01-03  EUR  2019-12-31   134.97
# 2018-01-04  EUR  2019-12-31   135.92
# 2018-01-05  EUR  2019-12-31   136.45
# 2018-01-08  EUR  2019-12-31   135.34
# ...         ...         ...      ...
# 2019-12-23  EUR  2019-12-31   121.18
# 2019-12-24  EUR  2019-12-31   121.19
# 2019-12-27  EUR  2019-12-31   122.23
# 2019-12-30  EUR  2019-12-31   122.19
# 2019-12-31  EUR  2019-12-31   121.94
#
# [510 rows x 5 columns]

# %%
x
x.json()['rates']['2018-01-02']['JPY'] # we just pull the Yen on that date
# Out:
# 135.35

# %%
pd.DataFrame(x.json())
# Out:
#                                                         rates    start_at  \
# 2018-01-02  {'CAD': 1.5128, 'HKD': 9.4283, 'SGD': 1.6031, ...  2018-01-02
#
#            base      end_at
# 2018-01-02  EUR  2018-01-02

# %%
rates_overview['rates'].mean
# Out:
# <bound method Series.mean of AUD       0.161831
# BGN       0.192500
# BRL       0.468199
# CAD       0.141762
# CHF       0.104380
# CNY       0.748474
# CZK       2.482874
# DKK       0.735246
# EUR       0.098425
# GBP       0.082313
# HKD       0.831152
# HRK       0.733927
# HUF      33.209646
# IDR    1485.698819
# ILS       0.365728
# INR       7.650000
# ISK      13.710630
# JPY      11.803150
# KRW     129.496063
# MXN       2.029380
# MYR       0.451634
# NOK       1.000000
# NZD       0.168898
# PHP       5.448819
# PLN       0.423346
# RON       0.473406
# RUB       6.967943
# SEK       1.040236
# SGD       0.149272
# THB       3.384843
# TRY       0.656378
# USD       0.106693
# ZAR       1.620561
# Name: rates, dtype: float64>
